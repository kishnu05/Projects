# %%
#aim: to forecast the WPI for a given series

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')
sns.set_style("darkgrid")

# %%
import sklearn
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ##2. Read and understand the Data

# %%
data_main=pd.read_csv('WPI_dataset.csv',index_col='date',parse_dates=True)
data_main.head()
# Out:
#               wpi  I    PRIMARY ARTICLES  (A).  FOOD ARTICLES  \
# date
# 2012-01-04  104.7                  107.1                106.2
# 2012-01-05  105.3                  107.5                106.7
# 2012-01-06  105.3                  107.9                109.3
# 2012-01-07  106.2                  111.4                111.3
# 2012-01-08  106.9                  112.7                111.2
#
#             a.  FOOD GRAINS (CEREALS+PULSES)  a1. CEREALS  Paddy  Wheat  \
# date
# 2012-01-04                             104.8        104.6  104.2  104.6
# 2012-01-05                             106.0        104.8  104.2  105.4
# 2012-01-06                             107.4        105.9  107.0  104.4
# 2012-01-07                             111.5        108.8  111.0  105.8
# 2012-01-08                             117.4        114.8  114.0  116.0
#
#             Jowar  Bajra  Maize  ...  Football  Table Tennis Table  \
# date                             ...
# 2012-01-04   98.3  107.7  107.9  ...     105.4               105.0
# 2012-01-05   98.2  109.3  105.5  ...     105.7               105.0
# 2012-01-06   97.0  107.0  107.2  ...     105.7               107.3
# 2012-01-07   93.7  113.9  111.3  ...     105.8               107.3
# 2012-01-08   96.2  120.7  117.8  ...     105.7               107.3
#
#             d. Manufacture of games and toys  Playing Cards  Carrom board  \
# date
# 2012-01-04                             104.6          101.7         107.4
# 2012-01-05                             104.8          102.5         107.5
# 2012-01-06                             105.9          105.3         107.5
# 2012-01-07                             105.5          105.1         107.4
# 2012-01-08                             104.3          104.1         107.6
#
#             Plastic moulded-others toys  Non Mechanical Toys  \
# date
# 2012-01-04                        106.7                107.0
# 2012-01-05                        106.3                107.0
# 2012-01-06                        106.0                107.0
# 2012-01-07                        105.3                107.0
# 2012-01-08                        103.7                107.0
#
#             e. Manufacture of medical and dental instruments and supplies  \
# date
# 2012-01-04                                              115.0
# 2012-01-05                                              115.0
# 2012-01-06                                              115.0
# 2012-01-07                                              115.0
# 2012-01-08                                              115.0
#
#             Intraocular Lens  IV FOOD INDEX
# date
# 2012-01-04             115.0          105.9
# 2012-01-05             115.0          106.5
# 2012-01-06             115.0          108.4
# 2012-01-07             115.0          110.4
# 2012-01-08             115.0          111.1
#
# [5 rows x 869 columns]

# %%
data_main.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
data_main.tail()
# Out:
#               wpi  I    PRIMARY ARTICLES  (A).  FOOD ARTICLES  \
# date
# 2023-01-03  151.0                  175.2                178.8
# 2023-01-04  151.1                  177.8                182.1
# 2023-01-05  149.4                  175.1                181.3
# 2023-01-06  149.0                  176.3                184.9
# 2023-01-07  151.9                  190.5                204.4
#
#             a.  FOOD GRAINS (CEREALS+PULSES)  a1. CEREALS  Paddy  Wheat  \
# date
# 2023-01-03                             183.0        183.6  175.4  187.1
# 2023-01-04                             183.7        183.5  176.2  186.4
# 2023-01-05                             183.2        183.1  177.2  184.9
# 2023-01-06                             185.2        184.5  178.2  187.3
# 2023-01-07                             187.4        186.4  181.2  187.5
#
#             Jowar  Bajra  Maize  ...  Football  Table Tennis Table  \
# date                             ...
# 2023-01-03  208.3  225.1  193.7  ...     155.5               145.1
# 2023-01-04  208.0  229.6  189.8  ...     159.7               145.1
# 2023-01-05  209.2  229.4  184.5  ...     160.8               145.1
# 2023-01-06  219.5  226.7  181.9  ...     158.9               145.1
# 2023-01-07  224.1  226.9  186.0  ...     158.9               145.7
#
#             d. Manufacture of games and toys  Playing Cards  Carrom board  \
# date
# 2023-01-03                             157.6          160.0         181.9
# 2023-01-04                             159.4          163.7         181.9
# 2023-01-05                             158.9          161.2         184.4
# 2023-01-06                             159.7          163.1         185.8
# 2023-01-07                             159.7          161.9         186.3
#
#             Plastic moulded-others toys  Non Mechanical Toys  \
# date
# 2023-01-03                        146.6                207.0
# 2023-01-04                        147.2                207.0
# 2023-01-05                        148.0                207.8
# 2023-01-06                        147.6                207.8
# 2023-01-07                        148.6                207.8
#
#             e. Manufacture of medical and dental instruments and supplies  \
# date
# 2023-01-03                                              166.3
# 2023-01-04                                              166.3
# 2023-01-05                                              163.6
# 2023-01-06                                              164.5
# 2023-01-07                                              164.5
#
#             Intraocular Lens  IV FOOD INDEX
# date
# 2023-01-03             166.3          172.1
# 2023-01-04             166.3          174.0
# 2023-01-05             163.6          172.9
# 2023-01-06             164.5          175.2
# 2023-01-07             164.5          187.7
#
# [5 rows x 869 columns]

# %%
data_main.shape
# Out:
# (136, 869)

# %%
wpi_data = data_main.iloc[:, [0]]

# %%
wpi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 136 entries, 2012-01-04 to 2023-01-07
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wpi     136 non-null    float64
# dtypes: float64(1)
# memory usage: 2.1 KB

# %%
#check the numerical data statitics ; finding any outliers or extreme minimum or maximum values
wpi_data.describe()
# Out:
#               wpi
# count  136.000000
# mean   121.431618
# std     14.141270
# min    104.700000
# 25%    111.475000
# 50%    116.350000
# 75%    123.450000
# max    154.000000

# %% [markdown]
# # Exploratory data analysis

# %%
wpi_data.isnull().sum() # to find missing values
# Out:
# wpi    0
# dtype: int64

# %% [markdown]
# # outliers rectification

# %%
wpi_data.describe(percentiles=[.25,0.5,0.75,0.90,0.95,0.99])
# Out:
#               wpi
# count  136.000000
# mean   121.431618
# std     14.141270
# min    104.700000
# 25%    111.475000
# 50%    116.350000
# 75%    123.450000
# 90%    149.950000
# 95%    151.900000
# 99%    154.000000
# max    154.000000

# %%
plt.figure(figsize=(12,6))
sns.boxplot(wpi_data['wpi']) #import seaborn as sns
plt.show()

# %% [markdown]
# observation: all the observed data is not too far from interquartile range

# %%
plt.figure(figsize=(12,6))
plt.hist(wpi_data['wpi'])
plt.show()

# %%
np.nanmedian(wpi_data['wpi'])
# Out:
# 116.35

# %% [markdown]
# # Data Preperation

# %%
wpi_data.head()
# Out:
#               wpi
# date
# 2012-01-04  104.7
# 2012-01-05  105.3
# 2012-01-06  105.3
# 2012-01-07  106.2
# 2012-01-08  106.9

# %% [markdown]
# ### Time series Decomposition

# %%
wpi_data.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.figure(figsize=(18,4))
plt.plot(wpi_data,label="index of All Commodities")
plt.legend(loc='best')
plt.title("WPI Data of All Commodities")
plt.xticks(rotation=90,fontweight="bold")
plt.show()

# %% [markdown]
# # Additive seasonal decomposition

# %%
from pylab import rcParams
from scipy.fftpack import fftfreq #fast courier transform
#fourier analysis is a method for exporessing as a sum of periodic components and for recovering the signal from those components

# %%
import statsmodels.api as sm

# %%
rcParams['figure.figsize']=12,8
decomposition=sm.tsa.seasonal_decompose(wpi_data['wpi'],model='additive',period=12) #additive seasonal
#print(decomposition.trend), #seasonal, .resid
fig=decomposition.plot()
plt.show()

# %% [markdown]
# # Multiplicative seasonal decomposition

# %%
decomposition=sm.tsa.seasonal_decompose(wpi_data['wpi'],model='multiplicative',period=12) #multiplicative seasonal
fig=decomposition.plot()
plt.show()

# %% [markdown]
# #### it is observed that a constant residual of 1 , so additive model is chose as residual error is 1 in multiplicative error
# Inference: the data contains level, trend but not seasonality

# %% [markdown]
# # Split the data into train and test series

# %%
train_len=122
train=wpi_data[0:train_len]
test=wpi_data[train_len : ]

# %%
train.head()
# Out:
#               wpi
# date
# 2012-01-04  104.7
# 2012-01-05  105.3
# 2012-01-06  105.3
# 2012-01-07  106.2
# 2012-01-08  106.9

# %%
test
# Out:
#               wpi
# date
# 2022-01-06  154.0
# 2022-01-07  154.0
# 2022-01-08  153.2
# 2022-01-09  151.9
# 2022-01-10  152.9
# 2022-01-11  152.5
# 2022-01-12  150.5
# 2023-01-01  150.7
# 2023-01-02  150.9
# 2023-01-03  151.0
# 2023-01-04  151.1
# 2023-01-05  149.4
# 2023-01-06  149.0
# 2023-01-07  151.9

# %% [markdown]
# we build a time series forecast model and compare the RMSE and MAPE values for the models . Lower values of RMSE are desired to conclude that a model performs better accurary .
# accuracy is calculated as 100 - MAPE. Lower the MAPE value, higher is the accurary

# %% [markdown]
# # Building an ARIMA Model for forecasting

# %% [markdown]
# #### To make the series stationary, we need to perform transformation and differencing

# %% [markdown]
# ### Check wether the time series is stationary

# %% [markdown]
# ##### average / mean / expected value of the time series is constant through out the different time period

# %% [markdown]
# ##### standard deviation / variance of the time series is constant throu out the different period

# %% [markdown]
# ##### there is no seasonality in the data

# %% [markdown]
# ### Augumented Dicky Fuller test (ADF)test : To inference if the time series is stationary or not using p-values

# %%
from statsmodels.tsa.stattools import adfuller

# %%
#hypothesis test
#Null hypothesis - the time series is stationary
#alternate hypothesis - the time series is not stationary

#p value < 0.05 # 95% confidence that you accept the null hypothesis - the  TS is stationary
#p-value >=0.05 # reject the Null hypothesis - TS is not stationary

# %%
adf_test= adfuller(wpi_data['wpi'])

# %%
print(adf_test)
# Out:
# (0.8200648492170557, 0.9919532446906909, 2, 133, {'1%': -3.480500383888377, '5%': -2.8835279559405045, '10%': -2.578495716547007}, 325.90420607677027)

# %%
print ('ADF Statistic : % f' %adf_test[0])
# Out:
# ADF Statistic :  0.820065

# %%
print('critical values @ 0.05 : %.2f' %adf_test[4]['5%'])
# Out:
# critical values @ 0.05 : -2.88

# %%
print('p-value : %f' %adf_test[1])
# Out:
# p-value : 0.991953

# %% [markdown]
# #### Inference : p-value is greater than 0.05, which means that the series is not stationary

# %% [markdown]
# ## Kwitkowski - phillips-schmidt-shin test (kpss)test

# %%
from statsmodels.tsa.stattools import kpss

# %%
kpss_test=kpss(wpi_data['wpi'])
# Out:
# C:\Users\gurut\AppData\Local\Temp\ipykernel_11880\3884877132.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_test=kpss(wpi_data['wpi'])

# %%
print('KPSS Statistic : %f' %kpss_test[0])
# Out:
# KPSS Statistic : 1.595203

# %%
print('Critical Values @ 0.05 : %.2f' %kpss_test[3]['5%'])
# Out:
# Critical Values @ 0.05 : 0.46

# %%
print('p-value : %f' % kpss_test[1])
# Out:
# p-value : 0.010000

# %% [markdown]
# #### Inference : p-value is less than 0.05, which means that the series is not stationary which is opposite to dickyfuller test

# %% [markdown]
# ## Box cox transformation to make variance constant #Differencing

# %% [markdown]
# differencing methodology
# upward trend TS Data
# intution
#
# 2,     3.5,   4,  5.5,  6.2,  7.5
# null    2,   3.5,  4,    5.5,  6.2,  7.5
#
# TS = Null, 1.5,0.5,1.5,0.7

# %% [markdown]
# TS which is not stationary
#
# ↓
#
# Transformation / differencing timeseries -> stationary
#
# ↓
#
# Model this stationary data using TS models
#
# ↓
#
# Predict the new values -> transformed TS
#
# ↓
#
# reverse transform the TS - > original data

# %%
print(wpi_data.columns)
wpi_data
# Out:
# Index(['wpi'], dtype='object')
#               wpi
# date
# 2012-01-04  104.7
# 2012-01-05  105.3
# 2012-01-06  105.3
# 2012-01-07  106.2
# 2012-01-08  106.9
# ...           ...
# 2023-01-03  151.0
# 2023-01-04  151.1
# 2023-01-05  149.4
# 2023-01-06  149.0
# 2023-01-07  151.9
#
# [136 rows x 1 columns]

# %%
from scipy.stats import boxcox #box,cox

# %% [markdown]
# Box-Cox Transformation : Transforms non-gaussian distribution data into gaussian ; power distributions to normal distributions and then shifting it by 1 unit and then differencing

# %%
data_boxcox=pd.Series(boxcox(wpi_data['wpi'], lmbda=0), index=wpi_data.index)
plt.figure(figsize=(12,4))
plt.plot(data_boxcox, label = 'after Box Cox transformation')
plt.legend(loc='best')
plt.title('after Box cox transformation \n', fontdict = { 'fontsize': 5, 'color':'Orange'})
plt.show()

# %% [markdown]
# ## Differencing to remove trend

# %%
# Compute differences in 'data_boxcox'

data_boxcox_diff = pd.Series(data_boxcox - data_boxcox.shift(), index=wpi_data.index)

plt.figure(figsize=(15,6))
plt.plot(data_boxcox_diff, label = "After Box Cox Transformation and Differencing")
plt.legend(loc='best')
plt.title ("After Box Cox transform and differencing \ n ", fontdict={'fontsize':16, 'fontweight' : 5, 'color' : "orange"})
plt.show()

# %%
# Now, 'data_boxcox_diff' contains the differences

print
(data_boxcox_diff)
# Out:
# date
# 2012-01-04         NaN
# 2012-01-05    0.005714
# 2012-01-06    0.000000
# 2012-01-07    0.008511
# 2012-01-08    0.006570
#                 ...
# 2023-01-03    0.000662
# 2023-01-04    0.000662
# 2023-01-05   -0.011315
# 2023-01-06   -0.002681
# 2023-01-07    0.019276
# Length: 136, dtype: float64

# %%
data_boxcox_diff.dropna(inplace=True) 
#after shifting the data, drop the first value which is NA

# %%
data_boxcox_diff.tail()
# Out:
# date
# 2023-01-03    0.000662
# 2023-01-04    0.000662
# 2023-01-05   -0.011315
# 2023-01-06   -0.002681
# 2023-01-07    0.019276
# dtype: float64

# %%
#check now again for series has become stationary or not

# %% [markdown]
# ## Augumented dicky fuller test

# %%
adf_test=adfuller(data_boxcox_diff)

print('ADF Statistic : % f' % adf_test[0])  #smaller value indicates higher stationarity, rejecting null hypothesis
print('p-value : %f' % adf_test[1])
print('Critical Values @ 0.05 : %.2f'% adf_test[4]['5%'])
# Out:
# ADF Statistic : -6.213553
# p-value : 0.000000
# Critical Values @ 0.05 : -2.88

# %%
#inference : p value is less than 0.05. which means that the series is stationary

# %% [markdown]
# ## Kwitkowski - phillips-schmidt-shin test (kpss)test

# %%
kpss_test=kpss(data_boxcox_diff)

print('KPSS Statistic : %f' %kpss_test[0])

print('Critical Values @ 0.05 : %.2f' %kpss_test[3]['5%'])

print('p-value : %f' % kpss_test[1])
# Out:
# KPSS Statistic : 0.252848
# Critical Values @ 0.05 : 0.46
# p-value : 0.100000
# C:\Users\gurut\AppData\Local\Temp\ipykernel_11880\289876631.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_test=kpss(data_boxcox_diff)

# %%
#inference: p-value is greater than 0.05. means the series is stationary

# %%
#another one order difference this time series become stationary so d will be 1

# %% [markdown]
# # Train-test-split

# %%
train_data_boxcox      = data_boxcox[:train_len]
test_data_box          = data_boxcox[train_len:]
train_data_boxcox_diff = data_boxcox_diff[:train_len-1]
test_data_boxcox_diff  = data_boxcox_diff[train_len-1:]

# %% [markdown]
# #### proceeding towards building various AR models to forecast the series

# %% [markdown]
# first we need to care of the assumptions about the data and determine the parameters of the ARIMA (p,d,q) model, for d we already have the value

# %% [markdown]
# the next step in the ARIMA model is computing'p', or the order for the autoregression model, we can inspect the autocorrelation plot, which measures the correlation between the time-series data and a certain lag. Based on the presense or absence or correlation, we can determine whether the lag or order is needed or not

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data_boxcox_diff)

# %% [markdown]
# so we estimated similarly by looking at the PACF plot instead of the ACF plot . looking at the number of lags crossing the threshold, we can determine how much of the past would be significant enough to consider for the future. the ones with high correlation contribute more and would be enough to predict future values. from the plots above Moving Average parameter can be observed between 7 and 9

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data_boxcox_diff)

# %% [markdown]
# ## fit ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data_boxcox_diff, order=(2, 1, 9))
model_fit = model.fit()

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\gurut\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\gurut\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\gurut\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\gurut\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
print(model_fit.params)
# Out:
# ar.L1    -0.129493
# ar.L2    -0.525076
# ma.L1    -0.193887
# ma.L2     0.183950
# ma.L3    -0.425089
# ma.L4    -0.355905
# ma.L5    -0.019891
# ma.L6     0.030742
# ma.L7    -0.027838
# ma.L8     0.072403
# ma.L9    -0.003654
# sigma2    0.000046
# dtype: float64

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  135
# Model:                 ARIMA(2, 1, 9)   Log Likelihood                 478.640
# Date:                Fri, 20 Oct 2023   AIC                           -933.280
# Time:                        05:15:25   BIC                           -898.506
# Sample:                             0   HQIC                          -919.149
#                                 - 135
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1295      1.140     -0.114      0.910      -2.364       2.105
# ar.L2         -0.5251      1.050     -0.500      0.617      -2.583       1.533
# ma.L1         -0.1939      1.150     -0.169      0.866      -2.448       2.060
# ma.L2          0.1840      1.177      0.156      0.876      -2.123       2.491
# ma.L3         -0.4251      0.456     -0.932      0.351      -1.319       0.469
# ma.L4         -0.3559      0.400     -0.890      0.374      -1.140       0.428
# ma.L5         -0.0199      0.307     -0.065      0.948      -0.621       0.581
# ma.L6          0.0307      0.285      0.108      0.914      -0.527       0.588
# ma.L7         -0.0278      0.229     -0.121      0.903      -0.477       0.422
# ma.L8          0.0724      0.212      0.342      0.733      -0.343       0.488
# ma.L9         -0.0037      0.172     -0.021      0.983      -0.340       0.333
# sigma2      4.573e-05   6.35e-06      7.204      0.000    3.33e-05    5.82e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.44
# Prob(Q):                              0.99   Prob(JB):                         0.80
# Heteroskedasticity (H):               1.98   Skew:                             0.10
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Recover original time series
y_hat_ar = data_boxcox_diff.copy()
y_hat_ar['ar_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox_diff'].cumsum()
y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox'].add(data_boxcox[0])
y_hat_ar['ar_forecast'] = np.exp(y_hat_ar['ar_forecast_boxcox'])

# %%
#Plot train, test and forecast

plt.figure(figsize=(12,4))
plt.plot(train['wpi'], label = 'Train')
plt.plot(train['wpi'], label = 'Test')
plt.plot(y_hat_ar['ar_forecast'] [test.index.min():], label='Auto regression forecast')
plt.legend(loc='best')
plt.title('Auto Regression Method')
plt.show()

# %% [markdown]
# Auto regressive model:
# current value - dependent on previous value (how many previous values ) - ACF
# Moving Average  - it depends on a lot of unknown cases - unpredictable inputs
# integrated - difference based model

# %%
# Calculate RMSE and MAPE
rmse = np.sqrt(mean_squared_error(test['wpi'], y_hat_ar['ar_forecast'][test.index.min():])).round(2)
mape = np.round(np.mean(np.abs(test['wpi']-y_hat_ar['ar_forecast'][test.index.min():])/test['wpi'])*100,2)
print(mape)
# Out:
# 1.4

# %%
future_predict=model_fit.predict(start = len(wpi_data), end = (len(wpi_data)) + 6)
future_predict = future_predict.cumsum()
future_predict = future_predict.add(data_boxcox[0])
future_predict = np.exp(future_predict)

# %%
future_predict.tail()
# Out:
# 138    106.089636
# 139    106.426705
# 140    106.894657
# 141    107.195782
# 142    107.576538
# Name: predicted_mean, dtype: float64

# %%
future_predict.plot()
plt.title('Next Six Months Prediction\n', fontdict={'fontsize': 16, 'fontweight' : 5, 'color': 'Orange'})
plt.show()
